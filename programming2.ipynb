# %%
# This program explores part of build-in functions
# plus some methods related strings and lists

# %%
x=3+4j

# %%
x
# Out:
# (3+4j)

# %%
print(abs(x))
# Out:
# 5.0

# %%
print(max(3,1,4))
# Out:
# 4

# %%
print(min(3,1,-4))
# Out:
# -4

# %%
pow(3,4,2)  # (3**4)%2
# Out:
# 1

# %%
print(pow(3,4))
# Out:
# 81

# %%
print(round(3.64))
# Out:
# 4

# %%
round(3.14159265,4)
# Out:
# 3.1416

# %%
print(round(3.64,1))
# Out:
# 3.6

# %%
# return a tuple of (index, value)
a=['hello']+['spring','summer',5,7]

# %%
a
# Out:
# ['hello', 'spring', 'summer', 5, 7]

# %%
for x, y in enumerate(a):
    print(x)
    print(y)
# Out:
# 0
# hello
# 1
# spring
# 2
# summer
# 3
# 5
# 4
# 7

# %%
x
# Out:
# 4

# %%
b=enumerate(a)

# %%
x=[5,2,3]
for i in x:
    print(i)
# Out:
# 5
# 2
# 3

# %%
b

# %%
print(list(b))
# Out:
# [(0, 'hello'), (1, 'spring'), (2, 'summer'), (3, 5), (4, 7)]

# %%
# test if all elements are true, 0==false
print(all([1,0,4,5]),all('hello'))
# Out:
# False True

# %%
# test if there is a true element
    
print(any([1,0,4,5]),any('hello'))
# Out:
# True True

# %%
# convert an integer to binary
print(bin(-5))
# Out:
# -0b101

# %%
bin(127)
# Out:
# '0b1111111'

# %%
oct(127)
# Out:
# '0o177'

# %%
hex(127)
# Out:
# '0x7f'

# %%
# convert decimal integers to hex string
print(hex(96))
# Out:
# 0x60

# %%
x=hex(ord('S'))

# %%
x
# Out:
# '0x53'

# %%
'%x' % eval(x)
# Out:
# '53'

# %%
'%#x' % 255, '%x' % 255, '%X' % 255
# Out ('0xff', 'ff', 'FF')
# Out:
# ('0xff', 'ff', 'FF')

# %%
oct(255)
# Out:
# '0o377'

# %%
# conver a decimal integer to octal
'%#o' % 10, '%o' % 10  #('0o12', '12')
# Out:
# ('0o12', '12')

# %%
oct(96)
# Out:
# '0o140'

# %%
# conver to boolean
print(bool('a'))
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(-2)
# Out:
# True

# %%
# integer to unicode or ascii
print(chr(int('0x41',16)))
# Out:
# A

# %%
int('0x41',16)
# Out:
# 65

# %%
print(chr(65))
# Out:
# A

# %%
# convert a string to complex, or complex(1,2)==1+2j
c=complex(3,4)
print(c)
# Out:
# (3+4j)

# %%
c=complex('7+6j')
print(c)
# Out:
# (7+6j)

# %%
# convert a string of expression to a value
    
eval('3+0xff')
# Out:
# 258

# %%
# build a new iterator from old iterable,if a function is true
    
a=[1,10, 25, 6, 15,8,47]
a
# Out:
# [1, 10, 25, 6, 15, 8, 47]

# %%
def big9(x):
   return x>9

# %%
list(filter(big9,a))
# Out:
# [10, 25, 15, 47]

# %%
# keep the items meet the function

print(list(filter(big9,a)))
# Out:
# [10, 25, 15, 47]

# %%
f=filter(big9,a)
for i in f:
    print(i)
# Out:
# 10
# 25
# 15
# 47

# %%
# return a new iterator with functions of input iterator
# run the function on each item

print(list(map(big9,a)))
# Out:
# [False, True, True, False, True, False, True]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 list(filter(list(map(big9,a)),a))
#
# TypeError: 'list' object is not callable

# %%
# convert a string to float a number
    
print(7+float('-3.94'))
# Out:
# 3.06

# %%
# convert a float or string to an integer
    
int(123.45)  #123
# Out:
# 123

# %%
int('123') #123
# Out:
# 123

# %%
int('   -12_345\n') #-12345
# Out:
# -12345

# %%
int('FACE', 16) #64206
# Out:
# 64206

# %%
int('0xface', 0) # 64206
# Out:
# 64206

# %%
int('01110011', base=2) #115
# Out:
# 115

# %%
# return the length of a string, tuple, list, dictionary
len('hello')
# Out:
# 5

# %%
# return the unicode number of a character
ord('A')
# Out:
# 65

# %%
# return the modulo of 2**5 % 3
pow(2,5,3)
# Out:
# 2

# %%
   
# read the element from a list in a reversed order
a=[1,3,5,10]
a
# Out:
# [1, 3, 5, 10]

# %%
list(reversed(a))
# Out:
# [10, 5, 3, 1]

# %%
import numpy as np

# %%
a
# Out:
# [1, 3, 5, 10]

# %%
a.reverse()
a
# Out:
# [10, 5, 3, 1]

# %%
for i in reversed(a):
    print(i)
# Out:
# 10
# 5
# 3
# 1

# %%
a
# Out:
# ['A',
#  'm',
#  'e',
#  'r',
#  'i',
#  'c',
#  'a',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'a',
#  ' ',
#  'b',
#  'e',
#  'a',
#  'u',
#  't',
#  'i',
#  'f',
#  'u',
#  'l',
#  ' ',
#  'c',
#  'o',
#  'u',
#  'n',
#  't',
#  'r',
#  'y']

# %%
print(a)  # the list is the same
# Out:
# [1, 3, 5, 10]

# %%
# reverse the elements in a list
print(a)
# Out:
# [1, 3, 5, 10]

# %%
a.reverse()
print(a)  # the list is different.
# Out:
# [10, 5, 3, 1]

# %%
a
# Out:
# [10, 5, 3, 1]

# %%
# split each character in a string
a=[x for x in 'America is a beautiful country']

# %%
a
# Out:
# ['A',
#  'm',
#  'e',
#  'r',
#  'i',
#  'c',
#  'a',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'a',
#  ' ',
#  'b',
#  'e',
#  'a',
#  'u',
#  't',
#  'i',
#  'f',
#  'u',
#  'l',
#  ' ',
#  'c',
#  'o',
#  'u',
#  'n',
#  't',
#  'r',
#  'y']

# %%
# split a string to a list, separated by spaces
b='America is a beautiful country'.split()
b
# Out:
# ['America', 'is', 'a', 'beautiful', 'country']

# %%
# return a sorted list from low to high
sorted(a)
# Out:
# [' ',
#  ' ',
#  ' ',
#  ' ',
#  'A',
#  'a',
#  'a',
#  'a',
#  'b',
#  'c',
#  'c',
#  'e',
#  'e',
#  'f',
#  'i',
#  'i',
#  'i',
#  'l',
#  'm',
#  'n',
#  'o',
#  'r',
#  'r',
#  's',
#  't',
#  't',
#  'u',
#  'u',
#  'u',
#  'y']

# %%
print(sorted(a))
print(a)
# Out:
# [' ', ' ', ' ', ' ', 'A', 'a', 'a', 'a', 'b', 'c', 'c', 'e', 'e', 'f', 'i', 'i', 'i', 'l', 'm', 'n', 'o', 'r', 'r', 's', 't', 't', 'u', 'u', 'u', 'y']
# ['A', 'm', 'e', 'r', 'i', 'c', 'a', ' ', 'i', 's', ' ', 'a', ' ', 'b', 'e', 'a', 'u', 't', 'i', 'f', 'u', 'l', ' ', 'c', 'o', 'u', 'n', 't', 'r', 'y']

# %%
# return a sorted list from high to low
sorted(a, reverse=True)
# Out:
# ['y',
#  'u',
#  'u',
#  'u',
#  't',
#  't',
#  's',
#  'r',
#  'r',
#  'o',
#  'n',
#  'm',
#  'l',
#  'i',
#  'i',
#  'i',
#  'f',
#  'e',
#  'e',
#  'c',
#  'c',
#  'b',
#  'a',
#  'a',
#  'a',
#  'A',
#  ' ',
#  ' ',
#  ' ',
#  ' ']

# %%
# replace the list with sorted elements
a=[1,10,3,5]

# %%
print(sorted(a))  # the old list is the same
print(a)
# Out:
# [1, 3, 5, 10]
# [1, 10, 3, 5]

# %%
a.sort() # the list is different
print(a)
# Out:
# [1, 3, 5, 10]

# %%
# add all elements of a list plus the start

# %%
a=[10,3,1,5]
sum(a,start=100)
# Out:
# 119

# %%
    
# return the type of the object

# %%
a=[10,3,1,5]
type(a)
# Out:
# list

# %%
# return the object number
id(a)
# Out:
# 2072704152064

# %%
a+[6]
# Out:
# [10, 3, 1, 5, 6]

# %%
id(a)
# Out:
# 2072704152064

# %%
b=a.copy()

# %%
b
# Out:
# [10, 3, 1, 5]

# %%
id(b)
# Out:
# 2072705111872

# %%
c=a

# %%
id(c)
# Out:
# 2072704152064

# %%
a='America is a beautiful country!'

# %%
cipher=[2,0,2,5,0,8,3,1]
b=[' ']*len(a)

# %%
for i in range(len(a)):
    b[i]=chr(ord(a[i])+cipher[i%8])

# %%
c=''.join(b)
c
# Out:
# 'Cmgwikd!ks"f jhbwtkkut#dqupyr\x81$'
