# %%
# this file teachs you how to write your first
# programs with Python,
# input, output, identifiers, arithmetic operators

# %%
# your 1st Python program
print('Hello World')
# Out:
# Hello World

# %%
# input to and output from a program
radius = eval(input('Please input the radius!'))
# Out:
# Please input the radius! 2

# %%
area=3.14159265*radius*radius

# %%
x=input('please input your numbers')
# Out:
# please input your numbers 55

# %%
eval(x)+5
# Out:
# 60

# %%
print('The area of the circle is ', area)
# Out:
# The area of the circle is  12.5663706

# %%
y=input('please input 2 numbers and a string')
# Out:
# please input 2 numbers and a string 2 100 hello

# %%
y.split()
# Out:
# ['2', '100', 'hello']

# %%
# take multiple input
a,b,c =input('Please input 2 numbers and a string').split()
# Out:
# Please input 2 numbers and a string 2.71828 3.14159265 Physics

# %%
eval(b)
# Out:
# 3.14159265

# %%
print(c,b,a)
# Out:
# Physics 3.14159265 2.71828

# %%
x=5
y=10
space=x
x=y
y=space
x,y
# Out:
# (10, 5)

# %%
# assign several values
x,y,z=20,3,400
print(x,y,z)
# Out:
# 20 3 400

# %%
# swap
x,y,z=z,x,y
print(x,y,z)
# Out:
# 400 20 3

# %%
# Arithmetic operators
print(3+8.2)
# Out:
# 11.2

# %%
print(20-3.4)
# Out:
# 16.6

# %%
print(3*6.18)
# Out:
# 18.54

# %%
print(20/3)
# Out:
# 6.666666666666667

# %%
print(20//-3)
# Out:
# -7

# %%
print(20**3)
# Out:
# 8000

# %%
print(20%3)
# Out:
# 2

# %%
# precedence, order of execution

print(3+5*2**3)  #43
# Out:
# 43

# %%
print((3+5)*2**3) #64
# Out:
# 64

# %%
print(3+(5*2)**3) #1003
# Out:
# 1003

# %%
# augmented assignment operators
t=2

# %%
t*=30
t
# Out:
# 60

# %%
t+=8
t
# Out:
# 68

# %%
t-=5
t
# Out:
# 63

# %%
t/=3
t
# Out:
# 21.0

# %%
t//=2
t
# Out:
# 10.0

# %%
t**=2
t
# Out:
# 100.0

# %%
t%=7
t
# Out:
# 2.0

# %%
print(int(3.8),round(3.8))
# Out:
# 3 4

# %%
int(3.8)
# Out:
# 3

# %%
round(3.8)
# Out:
# 4
